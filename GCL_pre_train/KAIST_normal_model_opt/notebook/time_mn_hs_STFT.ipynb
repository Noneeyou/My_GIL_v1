# %% [markdown]
# # normal_model

# %% [markdown]
# ## time pyd_data

# %%
# ================== 1️⃣ 导入路径与函数 ==================
# %run ../_init_path.py

import os
import torch
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.utils import subgraph, add_self_loops

# === 导入模型结构 ===
from models import GraphContrastiveLearner, augment_graph, summarize_graph


# ===================== 0️⃣ 路径设置 =====================
train_graph_path = "/home/charles/HZU/Data_processed/my_CIL_V1/KAIST/KAIST_high_similar_class/train/pyg/train_graph_with_labelmask.pt"
val_graph_path   = "/home/charles/HZU/Data_processed/my_CIL_V1/KAIST/KAIST_high_similar_class/val/pyg/graph.pt"
test_graph_path  = "/home/charles/HZU/Data_processed/my_CIL_V1/KAIST/KAIST_high_similar_class/test/pyg/graph.pt"

save_dir = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT"
os.makedirs(save_dir, exist_ok=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


from torch_geometric.utils import add_self_loops

# ===================== 1️⃣ 加载图数据 =====================
print("\n========== 加载 train 图（带 label mask） ==========")
train_data = torch.load(train_graph_path)
summarize_graph(train_data)

print("\n========== 加载 val 图 ==========")
val_data = torch.load(val_graph_path)

print("\n========== 加载 test 图 ==========")
test_data = torch.load(test_graph_path)

# ===================== 2️⃣ 添加自环 =====================

def add_self_loop_to_graph(data):
    # 如果图有 edge_attr，一并处理；否则只添加 edge_index
    if hasattr(data, "edge_attr") and data.edge_attr is not None:
        edge_index, edge_attr = add_self_loops(
            data.edge_index,
            data.edge_attr,
            num_nodes=data.num_nodes
        )
        data.edge_index = edge_index
        data.edge_attr = edge_attr
    else:
        edge_index, _ = add_self_loops(
            data.edge_index,
            num_nodes=data.num_nodes
        )
        data.edge_index = edge_index
    return data

# print("\n========== 为 train 图添加自环 ==========")
# train_data = add_self_loop_to_graph(train_data)

print("\n========== 为 val 图添加自环 ==========")
val_data = add_self_loop_to_graph(val_data)

print("\n========== 为 test 图添加自环 ==========")
test_data = add_self_loop_to_graph(test_data)

print("✅ 所有图均已成功加入自环！")



# ===================== 2️⃣ 对 train_data.x 做 Z-score 标准化 =====================
x_mean = train_data.x.mean(dim=0, keepdim=True)
x_std  = train_data.x.std(dim=0, keepdim=True) + 1e-6
train_data.x = (train_data.x - x_mean) / x_std

print("🎯 已完成 train_data.x 标准化")

x_mean = test_data.x.mean(dim=0, keepdim=True)
x_std  = test_data.x.std(dim=0, keepdim=True) + 1e-6
test_data.x = (test_data.x - x_mean) / x_std

print("🎯 已完成 test_data.x 标准化")

x_mean = val_data.x.mean(dim=0, keepdim=True)
x_std  = val_data.x.std(dim=0, keepdim=True) + 1e-6
val_data.x = (val_data.x - x_mean) / x_std

print("🎯 已完成 val_data.x 标准化")

# ===================== 3️⃣ 构造 batch 子图 =====================
batch_size = 1024
num_nodes = train_data.num_nodes

perm = torch.randperm(num_nodes)

batches = []
for i in range(0, num_nodes, batch_size):
    node_idx = perm[i:i + batch_size]

    # ---- 提取子图（必须 CPU）----
    sub_edge_index, _ = subgraph(
        node_idx,
        train_data.edge_index,
        relabel_nodes=True
    )

    sub_x = train_data.x[node_idx]

    # ---------- ⭐ 加入自环 ----------
    sub_edge_index, _ = add_self_loops(
        sub_edge_index, num_nodes=sub_x.size(0)
    )

    sub_data = Data(
        x=sub_x,
        edge_index=sub_edge_index,
    )
    batches.append(sub_data)

print(f"📌 共生成 {len(batches)} 个子图 batch")

loader = DataLoader(batches, batch_size=1, shuffle=True)


# ===================== 4️⃣ 初始化模型 =====================
in_dim = train_data.x.size(1)
hidden_dim = 256
out_dim = 256
proj_dim = 128
tau = 0.5

model = GraphContrastiveLearner(in_dim, hidden_dim, out_dim, proj_dim, tau).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
# Out:
# ✅ 已添加路径：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt
# ✅ 已添加 my_lib：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/src
#
# ========== 加载 train 图（带 label mask） ==========
#
# ============================================================
# 🧩 Graph Data Summary
# ============================================================
# 📊 节点数量 (num_nodes): 584
# 📈 节点特征维度 (num_features): 132
# 🔗 边数量 (num_edges): 11680
# 🔁 自环数量 (self-loops): 0
# 🎯 标签维度 (y_dim): torch.Size([584])
#
# 🧾 Data对象包含字段: ['train_nolabel_mask', 'x', 'edge_index', 'train_withlabel_mask', 'y']
# ============================================================
#
#
# ========== 加载 val 图 ==========
#
# ========== 加载 test 图 ==========
#
# ========== 为 val 图添加自环 ==========
#
# ========== 为 test 图添加自环 ==========
# ✅ 所有图均已成功加入自环！
# 🎯 已完成 train_data.x 标准化
# /tmp/ipykernel_11988/3394727987.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_data = torch.load(train_graph_path)
# /tmp/ipykernel_11988/3394727987.py:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_data = torch.load(val_graph_path)
# /tmp/ipykernel_11988/3394727987.py:36: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_data = torch.load(test_graph_path)
# 🎯 已完成 test_data.x 标准化
# 🎯 已完成 val_data.x 标准化
# 📌 共生成 1 个子图 batch

# %% [markdown]
# ## 训练

# %%
# ===================== 5️⃣ Batch 训练 =====================
epochs = 200

best_loss = float("inf")
best_model_path = os.path.join(save_dir, f"KAIST_normal_pretrain_best.pt")

print("\n================= 🚀 开始 Batch 对比学习训练 =================\n")

for epoch in range(1, epochs + 1):
    model.train()
    total_loss = 0.0

    for batch_data in loader:
        batch_data = batch_data[0].to(device)   # batch_size=1 → 取第 0 个

        # ---- 生成两份增强视图 ----
        data1 = augment_graph(
            batch_data,
            feature_drop_prob=0.2,
            edge_drop_prob=0.1,
            noise_std=0.02
        ).to(device)

        data2 = augment_graph(
            batch_data,
            feature_drop_prob=0.2,
            edge_drop_prob=0.1,
            noise_std=0.02
        ).to(device)

        # ---- 计算 InfoNCE 对比损失 ----
        loss = model.compute_loss(
            data1.x, data1.edge_index,
            data2.x, data2.edge_index
        )

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # ======== 日志输出 ========
    if epoch % 10 == 0:
        print(f"Epoch [{epoch:03d}/{epochs}] | InfoNCE Loss: {total_loss:.4f}")

    # ======== 保存当前最优模型 ========
    if total_loss < best_loss:
        best_loss = total_loss

        torch.save({
            "model_state_dict": model.state_dict(),
            "best_loss": best_loss,
            "epoch": epoch,
            "config": {
                "in_dim": in_dim,
                "hidden_dim": hidden_dim,
                "out_dim": out_dim,
                "proj_dim": proj_dim,
                "tau": tau
            }
        }, best_model_path)

        print(f"💾 [BEST MODEL UPDATED] Epoch {epoch} | Loss={total_loss:.4f}")


# ===================== 最终模型保存 =====================
final_path = os.path.join(save_dir, f"KAIST_normal_pretrain_epoch{epochs}.pt")
torch.save({
    "model_state_dict": model.state_dict(),
    "epoch": epochs,
    "config": {
        "in_dim": in_dim,
        "hidden_dim": hidden_dim,
        "out_dim": out_dim,
        "proj_dim": proj_dim,
        "tau": tau
    }
}, final_path)

print(f"\n🏁 最终模型已保存至: {final_path}")
print(f"🏆 最优模型已保存至: {best_model_path} | best_loss={best_loss:.4f}")
# Out:
# ================= 🚀 开始 Batch 对比学习训练 =================
#
# 💾 [BEST MODEL UPDATED] Epoch 1 | Loss=6.3044
# 💾 [BEST MODEL UPDATED] Epoch 2 | Loss=6.0554
# 💾 [BEST MODEL UPDATED] Epoch 3 | Loss=5.7902
# 💾 [BEST MODEL UPDATED] Epoch 4 | Loss=5.7066
# 💾 [BEST MODEL UPDATED] Epoch 5 | Loss=5.5737
# 💾 [BEST MODEL UPDATED] Epoch 6 | Loss=5.5259
# 💾 [BEST MODEL UPDATED] Epoch 7 | Loss=5.4902
# 💾 [BEST MODEL UPDATED] Epoch 8 | Loss=5.4587
# 💾 [BEST MODEL UPDATED] Epoch 9 | Loss=5.4370
# Epoch [010/200] | InfoNCE Loss: 5.4019
# 💾 [BEST MODEL UPDATED] Epoch 10 | Loss=5.4019
# 💾 [BEST MODEL UPDATED] Epoch 11 | Loss=5.3776
# 💾 [BEST MODEL UPDATED] Epoch 12 | Loss=5.3577
# 💾 [BEST MODEL UPDATED] Epoch 13 | Loss=5.3491
# 💾 [BEST MODEL UPDATED] Epoch 14 | Loss=5.3215
# 💾 [BEST MODEL UPDATED] Epoch 15 | Loss=5.2887
# 💾 [BEST MODEL UPDATED] Epoch 16 | Loss=5.2795
# 💾 [BEST MODEL UPDATED] Epoch 17 | Loss=5.2707
# 💾 [BEST MODEL UPDATED] Epoch 18 | Loss=5.2505
# 💾 [BEST MODEL UPDATED] Epoch 19 | Loss=5.2352
# Epoch [020/200] | InfoNCE Loss: 5.2323
# 💾 [BEST MODEL UPDATED] Epoch 20 | Loss=5.2323
# 💾 [BEST MODEL UPDATED] Epoch 21 | Loss=5.2201
# 💾 [BEST MODEL UPDATED] Epoch 22 | Loss=5.2064
# 💾 [BEST MODEL UPDATED] Epoch 23 | Loss=5.1973
# 💾 [BEST MODEL UPDATED] Epoch 24 | Loss=5.1876
# 💾 [BEST MODEL UPDATED] Epoch 25 | Loss=5.1811
# 💾 [BEST MODEL UPDATED] Epoch 26 | Loss=5.1637
# 💾 [BEST MODEL UPDATED] Epoch 27 | Loss=5.1590
# 💾 [BEST MODEL UPDATED] Epoch 28 | Loss=5.1516
# 💾 [BEST MODEL UPDATED] Epoch 29 | Loss=5.1469
# Epoch [030/200] | InfoNCE Loss: 5.1345
# 💾 [BEST MODEL UPDATED] Epoch 30 | Loss=5.1345
# 💾 [BEST MODEL UPDATED] Epoch 31 | Loss=5.1327
# 💾 [BEST MODEL UPDATED] Epoch 32 | Loss=5.1220
# 💾 [BEST MODEL UPDATED] Epoch 33 | Loss=5.1110
# 💾 [BEST MODEL UPDATED] Epoch 34 | Loss=5.1052
# 💾 [BEST MODEL UPDATED] Epoch 35 | Loss=5.0990
# 💾 [BEST MODEL UPDATED] Epoch 36 | Loss=5.0890
# 💾 [BEST MODEL UPDATED] Epoch 37 | Loss=5.0828
# 💾 [BEST MODEL UPDATED] Epoch 38 | Loss=5.0728
# 💾 [BEST MODEL UPDATED] Epoch 39 | Loss=5.0692
# Epoch [040/200] | InfoNCE Loss: 5.0650
# 💾 [BEST MODEL UPDATED] Epoch 40 | Loss=5.0650
# 💾 [BEST MODEL UPDATED] Epoch 41 | Loss=5.0533
# 💾 [BEST MODEL UPDATED] Epoch 42 | Loss=5.0460
# 💾 [BEST MODEL UPDATED] Epoch 43 | Loss=5.0407
# 💾 [BEST MODEL UPDATED] Epoch 44 | Loss=5.0337
# 💾 [BEST MODEL UPDATED] Epoch 45 | Loss=5.0289
# 💾 [BEST MODEL UPDATED] Epoch 46 | Loss=5.0196
# 💾 [BEST MODEL UPDATED] Epoch 47 | Loss=5.0134
# 💾 [BEST MODEL UPDATED] Epoch 48 | Loss=5.0125
# 💾 [BEST MODEL UPDATED] Epoch 49 | Loss=4.9984
# Epoch [050/200] | InfoNCE Loss: 4.9952
# 💾 [BEST MODEL UPDATED] Epoch 50 | Loss=4.9952
# 💾 [BEST MODEL UPDATED] Epoch 51 | Loss=4.9877
# 💾 [BEST MODEL UPDATED] Epoch 52 | Loss=4.9812
# 💾 [BEST MODEL UPDATED] Epoch 53 | Loss=4.9765
# 💾 [BEST MODEL UPDATED] Epoch 54 | Loss=4.9686
# 💾 [BEST MODEL UPDATED] Epoch 55 | Loss=4.9624
# 💾 [BEST MODEL UPDATED] Epoch 56 | Loss=4.9535
# 💾 [BEST MODEL UPDATED] Epoch 57 | Loss=4.9522
# 💾 [BEST MODEL UPDATED] Epoch 58 | Loss=4.9399
# 💾 [BEST MODEL UPDATED] Epoch 59 | Loss=4.9356
# Epoch [060/200] | InfoNCE Loss: 4.9276
# 💾 [BEST MODEL UPDATED] Epoch 60 | Loss=4.9276
# 💾 [BEST MODEL UPDATED] Epoch 61 | Loss=4.9252
# 💾 [BEST MODEL UPDATED] Epoch 62 | Loss=4.9149
# 💾 [BEST MODEL UPDATED] Epoch 63 | Loss=4.9095
# 💾 [BEST MODEL UPDATED] Epoch 64 | Loss=4.9026
# 💾 [BEST MODEL UPDATED] Epoch 65 | Loss=4.8962
# 💾 [BEST MODEL UPDATED] Epoch 66 | Loss=4.8883
# 💾 [BEST MODEL UPDATED] Epoch 67 | Loss=4.8819
# 💾 [BEST MODEL UPDATED] Epoch 68 | Loss=4.8741
# 💾 [BEST MODEL UPDATED] Epoch 69 | Loss=4.8659
# Epoch [070/200] | InfoNCE Loss: 4.8614
# 💾 [BEST MODEL UPDATED] Epoch 70 | Loss=4.8614
# 💾 [BEST MODEL UPDATED] Epoch 71 | Loss=4.8538
# 💾 [BEST MODEL UPDATED] Epoch 72 | Loss=4.8508
# 💾 [BEST MODEL UPDATED] Epoch 73 | Loss=4.8428
# 💾 [BEST MODEL UPDATED] Epoch 74 | Loss=4.8347
# 💾 [BEST MODEL UPDATED] Epoch 75 | Loss=4.8262
# 💾 [BEST MODEL UPDATED] Epoch 77 | Loss=4.8126
# 💾 [BEST MODEL UPDATED] Epoch 78 | Loss=4.8085
# 💾 [BEST MODEL UPDATED] Epoch 79 | Loss=4.8024
# Epoch [080/200] | InfoNCE Loss: 4.7940
# 💾 [BEST MODEL UPDATED] Epoch 80 | Loss=4.7940
# 💾 [BEST MODEL UPDATED] Epoch 81 | Loss=4.7868
# 💾 [BEST MODEL UPDATED] Epoch 82 | Loss=4.7814
# 💾 [BEST MODEL UPDATED] Epoch 83 | Loss=4.7720
# 💾 [BEST MODEL UPDATED] Epoch 84 | Loss=4.7684
# 💾 [BEST MODEL UPDATED] Epoch 85 | Loss=4.7573
# 💾 [BEST MODEL UPDATED] Epoch 86 | Loss=4.7523
# 💾 [BEST MODEL UPDATED] Epoch 87 | Loss=4.7393
# 💾 [BEST MODEL UPDATED] Epoch 88 | Loss=4.7333
# 💾 [BEST MODEL UPDATED] Epoch 89 | Loss=4.7308
# Epoch [090/200] | InfoNCE Loss: 4.7221
# 💾 [BEST MODEL UPDATED] Epoch 90 | Loss=4.7221
# 💾 [BEST MODEL UPDATED] Epoch 91 | Loss=4.7157
# 💾 [BEST MODEL UPDATED] Epoch 92 | Loss=4.7062
# 💾 [BEST MODEL UPDATED] Epoch 93 | Loss=4.7007
# 💾 [BEST MODEL UPDATED] Epoch 94 | Loss=4.6910
# 💾 [BEST MODEL UPDATED] Epoch 95 | Loss=4.6830
# 💾 [BEST MODEL UPDATED] Epoch 96 | Loss=4.6769
# 💾 [BEST MODEL UPDATED] Epoch 97 | Loss=4.6690
# 💾 [BEST MODEL UPDATED] Epoch 98 | Loss=4.6573
# 💾 [BEST MODEL UPDATED] Epoch 99 | Loss=4.6519
# Epoch [100/200] | InfoNCE Loss: 4.6474
# 💾 [BEST MODEL UPDATED] Epoch 100 | Loss=4.6474
# 💾 [BEST MODEL UPDATED] Epoch 101 | Loss=4.6356
# 💾 [BEST MODEL UPDATED] Epoch 102 | Loss=4.6287
# 💾 [BEST MODEL UPDATED] Epoch 103 | Loss=4.6224
# 💾 [BEST MODEL UPDATED] Epoch 104 | Loss=4.6165
# 💾 [BEST MODEL UPDATED] Epoch 105 | Loss=4.6059
# 💾 [BEST MODEL UPDATED] Epoch 106 | Loss=4.5954
# 💾 [BEST MODEL UPDATED] Epoch 107 | Loss=4.5887
# 💾 [BEST MODEL UPDATED] Epoch 108 | Loss=4.5818
# 💾 [BEST MODEL UPDATED] Epoch 109 | Loss=4.5744
# Epoch [110/200] | InfoNCE Loss: 4.5625
# 💾 [BEST MODEL UPDATED] Epoch 110 | Loss=4.5625
# 💾 [BEST MODEL UPDATED] Epoch 111 | Loss=4.5517
# 💾 [BEST MODEL UPDATED] Epoch 112 | Loss=4.5446
# 💾 [BEST MODEL UPDATED] Epoch 113 | Loss=4.5397
# 💾 [BEST MODEL UPDATED] Epoch 114 | Loss=4.5298
# 💾 [BEST MODEL UPDATED] Epoch 115 | Loss=4.5216
# 💾 [BEST MODEL UPDATED] Epoch 116 | Loss=4.5122
# 💾 [BEST MODEL UPDATED] Epoch 117 | Loss=4.5020
# 💾 [BEST MODEL UPDATED] Epoch 118 | Loss=4.4936
# 💾 [BEST MODEL UPDATED] Epoch 119 | Loss=4.4863
# Epoch [120/200] | InfoNCE Loss: 4.4750
# 💾 [BEST MODEL UPDATED] Epoch 120 | Loss=4.4750
# 💾 [BEST MODEL UPDATED] Epoch 121 | Loss=4.4634
# 💾 [BEST MODEL UPDATED] Epoch 122 | Loss=4.4557
# 💾 [BEST MODEL UPDATED] Epoch 123 | Loss=4.4447
# 💾 [BEST MODEL UPDATED] Epoch 124 | Loss=4.4345
# 💾 [BEST MODEL UPDATED] Epoch 125 | Loss=4.4282
# 💾 [BEST MODEL UPDATED] Epoch 126 | Loss=4.4169
# 💾 [BEST MODEL UPDATED] Epoch 127 | Loss=4.4091
# 💾 [BEST MODEL UPDATED] Epoch 128 | Loss=4.3981
# 💾 [BEST MODEL UPDATED] Epoch 129 | Loss=4.3867
# Epoch [130/200] | InfoNCE Loss: 4.3800
# 💾 [BEST MODEL UPDATED] Epoch 130 | Loss=4.3800
# 💾 [BEST MODEL UPDATED] Epoch 131 | Loss=4.3692
# 💾 [BEST MODEL UPDATED] Epoch 132 | Loss=4.3588
# 💾 [BEST MODEL UPDATED] Epoch 133 | Loss=4.3486
# 💾 [BEST MODEL UPDATED] Epoch 134 | Loss=4.3399
# 💾 [BEST MODEL UPDATED] Epoch 135 | Loss=4.3266
# 💾 [BEST MODEL UPDATED] Epoch 136 | Loss=4.3172
# 💾 [BEST MODEL UPDATED] Epoch 137 | Loss=4.3037
# 💾 [BEST MODEL UPDATED] Epoch 138 | Loss=4.2933
# 💾 [BEST MODEL UPDATED] Epoch 139 | Loss=4.2832
# Epoch [140/200] | InfoNCE Loss: 4.2739
# 💾 [BEST MODEL UPDATED] Epoch 140 | Loss=4.2739
# 💾 [BEST MODEL UPDATED] Epoch 141 | Loss=4.2620
# 💾 [BEST MODEL UPDATED] Epoch 142 | Loss=4.2494
# 💾 [BEST MODEL UPDATED] Epoch 143 | Loss=4.2401
# 💾 [BEST MODEL UPDATED] Epoch 144 | Loss=4.2299
# 💾 [BEST MODEL UPDATED] Epoch 145 | Loss=4.2141
# 💾 [BEST MODEL UPDATED] Epoch 146 | Loss=4.2069
# 💾 [BEST MODEL UPDATED] Epoch 147 | Loss=4.1938
# 💾 [BEST MODEL UPDATED] Epoch 148 | Loss=4.1831
# 💾 [BEST MODEL UPDATED] Epoch 149 | Loss=4.1685
# Epoch [150/200] | InfoNCE Loss: 4.1567
# 💾 [BEST MODEL UPDATED] Epoch 150 | Loss=4.1567
# 💾 [BEST MODEL UPDATED] Epoch 151 | Loss=4.1453
# 💾 [BEST MODEL UPDATED] Epoch 152 | Loss=4.1356
# 💾 [BEST MODEL UPDATED] Epoch 153 | Loss=4.1221
# 💾 [BEST MODEL UPDATED] Epoch 154 | Loss=4.1072
# 💾 [BEST MODEL UPDATED] Epoch 155 | Loss=4.0951
# 💾 [BEST MODEL UPDATED] Epoch 156 | Loss=4.0795
# 💾 [BEST MODEL UPDATED] Epoch 157 | Loss=4.0683
# 💾 [BEST MODEL UPDATED] Epoch 158 | Loss=4.0544
# 💾 [BEST MODEL UPDATED] Epoch 159 | Loss=4.0412
# Epoch [160/200] | InfoNCE Loss: 4.0265
# 💾 [BEST MODEL UPDATED] Epoch 160 | Loss=4.0265
# 💾 [BEST MODEL UPDATED] Epoch 161 | Loss=4.0094
# 💾 [BEST MODEL UPDATED] Epoch 162 | Loss=3.9994
# 💾 [BEST MODEL UPDATED] Epoch 163 | Loss=3.9884
# 💾 [BEST MODEL UPDATED] Epoch 164 | Loss=3.9707
# 💾 [BEST MODEL UPDATED] Epoch 165 | Loss=3.9566
# 💾 [BEST MODEL UPDATED] Epoch 166 | Loss=3.9442
# 💾 [BEST MODEL UPDATED] Epoch 167 | Loss=3.9277
# 💾 [BEST MODEL UPDATED] Epoch 168 | Loss=3.9160
# 💾 [BEST MODEL UPDATED] Epoch 169 | Loss=3.8966
# Epoch [170/200] | InfoNCE Loss: 3.8819
# 💾 [BEST MODEL UPDATED] Epoch 170 | Loss=3.8819
# 💾 [BEST MODEL UPDATED] Epoch 171 | Loss=3.8677
# 💾 [BEST MODEL UPDATED] Epoch 172 | Loss=3.8522
# 💾 [BEST MODEL UPDATED] Epoch 173 | Loss=3.8350
# 💾 [BEST MODEL UPDATED] Epoch 174 | Loss=3.8218
# 💾 [BEST MODEL UPDATED] Epoch 175 | Loss=3.8017
# 💾 [BEST MODEL UPDATED] Epoch 176 | Loss=3.7859
# 💾 [BEST MODEL UPDATED] Epoch 177 | Loss=3.7679
# 💾 [BEST MODEL UPDATED] Epoch 178 | Loss=3.7566
# 💾 [BEST MODEL UPDATED] Epoch 179 | Loss=3.7355
# Epoch [180/200] | InfoNCE Loss: 3.7165
# 💾 [BEST MODEL UPDATED] Epoch 180 | Loss=3.7165
# 💾 [BEST MODEL UPDATED] Epoch 181 | Loss=3.7035
# 💾 [BEST MODEL UPDATED] Epoch 182 | Loss=3.6830
# 💾 [BEST MODEL UPDATED] Epoch 183 | Loss=3.6674
# 💾 [BEST MODEL UPDATED] Epoch 184 | Loss=3.6477
# 💾 [BEST MODEL UPDATED] Epoch 185 | Loss=3.6283
# 💾 [BEST MODEL UPDATED] Epoch 186 | Loss=3.6115
# 💾 [BEST MODEL UPDATED] Epoch 187 | Loss=3.5884
# 💾 [BEST MODEL UPDATED] Epoch 188 | Loss=3.5714
# 💾 [BEST MODEL UPDATED] Epoch 189 | Loss=3.5554
# Epoch [190/200] | InfoNCE Loss: 3.5329
# 💾 [BEST MODEL UPDATED] Epoch 190 | Loss=3.5329
# 💾 [BEST MODEL UPDATED] Epoch 191 | Loss=3.5127
# 💾 [BEST MODEL UPDATED] Epoch 192 | Loss=3.4907
# 💾 [BEST MODEL UPDATED] Epoch 193 | Loss=3.4709
# 💾 [BEST MODEL UPDATED] Epoch 194 | Loss=3.4493
# 💾 [BEST MODEL UPDATED] Epoch 195 | Loss=3.4363
# 💾 [BEST MODEL UPDATED] Epoch 196 | Loss=3.4128
# 💾 [BEST MODEL UPDATED] Epoch 197 | Loss=3.3885
# 💾 [BEST MODEL UPDATED] Epoch 198 | Loss=3.3628
# 💾 [BEST MODEL UPDATED] Epoch 199 | Loss=3.3427
# Epoch [200/200] | InfoNCE Loss: 3.3219
# 💾 [BEST MODEL UPDATED] Epoch 200 | Loss=3.3219
#
# 🏁 最终模型已保存至: /home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/KAIST_normal_pretrain_epoch200.pt
# 🏆 最优模型已保存至: /home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/KAIST_normal_pretrain_best.pt | best_loss=3.3219

# %% [markdown]
# ## 效果可视化

# %%
# ======================================================================
#                ⭐ 单 Cell：不会报错的模型加载 + Train/Test 3D 可视化 ⭐
# ======================================================================

# ====================== 环境导入 ======================
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import umap
from mpl_toolkits.mplot3d import Axes3D

# ====================== 路径 ======================
save_dir = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/result/time_mn_hs_STFT"
os.makedirs(save_dir, exist_ok=True)

model_path = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/KAIST_normal_pretrain_best.pt"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ====================== 加载训练时的真实模型结构 ======================
from models import GraphContrastiveLearner   

# ----- 加载 checkpoint -----
checkpoint = torch.load(model_path, map_location=device)
cfg = checkpoint["config"]

# ----- 按训练时的方式实例化模型（不会报错 👍）-----
model = GraphContrastiveLearner(
    in_dim     = cfg["in_dim"],
    hidden_dim = cfg["hidden_dim"],
    out_dim    = cfg["out_dim"],
    proj_dim   = cfg["proj_dim"],
    tau        = cfg["tau"] if "tau" in cfg else 0.5
).to(device)

# ----- 加载权重（不会报错 👍）-----
model.load_state_dict(checkpoint["model_state_dict"])
model.eval()

print("✅ 使用训练时的原始模型读取成功！不会报错")

# ======================================================================
#                ⭐ 1️⃣ 提取 Train 和 Test 的嵌入
# ======================================================================

# 你前面已经：train_data / test_data = torch.load(...)
train_data = train_data.to(device)
test_data  = test_data.to(device)

with torch.no_grad():
    _, z_train = model(train_data.x, train_data.edge_index)
    _, z_test  = model(test_data.x,  test_data.edge_index)

train_emb = z_train.cpu().numpy()
test_emb  = z_test.cpu().numpy()

train_labels = train_data.y.cpu().numpy() if hasattr(train_data, "y") else np.zeros(train_emb.shape[0])
test_labels  = test_data.y.cpu().numpy() if hasattr(test_data,  "y") else np.zeros(test_emb.shape[0])

print(f"⭐ Train Embeddings Shape: {train_emb.shape}")
print(f"⭐ Test  Embeddings Shape: {test_emb.shape}")

# ======================================================================
#                ⭐ 2️⃣ 3D UMAP 降维
# ======================================================================
reducer_train = umap.UMAP(
    n_neighbors=10, min_dist=0.1, n_components=3,
    metric="cosine", random_state=42
)
train_umap = reducer_train.fit_transform(train_emb)

reducer_test = umap.UMAP(
    n_neighbors=10, min_dist=0.1, n_components=3,
    metric="cosine", random_state=42
)
test_umap = reducer_test.fit_transform(test_emb)

# ======================================================================
#                ⭐ 3️⃣ 绘制 Train 3D UMAP
# ======================================================================
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection="3d")

scatter = ax.scatter(
    train_umap[:,0], train_umap[:,1], train_umap[:,2],
    c=train_labels, cmap='tab20', s=8, alpha=0.85
)

ax.set_title("Train Graph Embeddings - 3D UMAP")
ax.set_xlabel("UMAP-1"); ax.set_ylabel("UMAP-2"); ax.set_zlabel("UMAP-3")

legend = plt.legend(
    *scatter.legend_elements(num=None),
    title="Labels", loc="center left", bbox_to_anchor=(1.02, 0.5), fontsize=8
)
ax.add_artist(legend)

plt.tight_layout(rect=[0,0,0.85,1])
plt.savefig(os.path.join(save_dir, "train_umap_3d.png"), dpi=300)
plt.show()

# ======================================================================
#                ⭐ 4️⃣ 绘制 Test 3D UMAP
# ======================================================================
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection="3d")

scatter = ax.scatter(
    test_umap[:,0], test_umap[:,1], test_umap[:,2],
    c=test_labels, cmap='tab20', s=8, alpha=0.85
)

ax.set_title("Test Graph Embeddings - 3D UMAP")
ax.set_xlabel("UMAP-1"); ax.set_ylabel("UMAP-2"); ax.set_zlabel("UMAP-3")

legend = plt.legend(
    *scatter.legend_elements(num=None),
    title="Labels", loc="center left", bbox_to_anchor=(1.02, 0.5), fontsize=8
)
ax.add_artist(legend)

plt.tight_layout(rect=[0,0,0.85,1])
plt.savefig(os.path.join(save_dir, "test_umap_3d.png"), dpi=300)
plt.show()

# ======================================================================
#                ⭐ 5️⃣ 保存嵌入
# ======================================================================
np.save(os.path.join(save_dir, "train_emb.npy"), train_emb)
np.save(os.path.join(save_dir, "train_umap_3d.npy"), train_umap)
np.save(os.path.join(save_dir, "test_emb.npy"),  test_emb)
np.save(os.path.join(save_dir, "test_umap_3d.npy"),  test_umap)

print("\n🎯 Train / Test 3D UMAP 全部完成并保存！")
# Out:
# /tmp/ipykernel_11988/2289585970.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# /home/charles/miniconda3/envs/d2l/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ 使用训练时的原始模型读取成功！不会报错
# ⭐ Train Embeddings Shape: (584, 128)
# ⭐ Test  Embeddings Shape: (291, 128)
# /home/charles/miniconda3/envs/d2l/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 🎯 Train / Test 3D UMAP 全部完成并保存！

# %% [markdown]
# ## 下游训练

# %%
# ======================================================================
#        ⭐ 单 Cell：使用 train_withlabel_mask 整图训练下游分类器（含 val 验证集） ⭐
# ======================================================================
# %run ../_init_path.py
from models import GraphContrastiveLearner, DownstreamClassifier

import torch
import torch.nn.functional as F
from torch.optim import Adam

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ======================================================================
# 1. 提取 train、val 的 encoder 表征
# ======================================================================

train_data = train_data.to(device)
val_data   = val_data.to(device)

model = model.to(device)
model.eval()

print("🚀 提取 train/val 编码特征（Encoder forward）...")

with torch.no_grad():
    h_train, _ = model(train_data.x, train_data.edge_index)
    h_val,   _ = model(val_data.x,   val_data.edge_index)

h_train = h_train.detach()
h_val   = h_val.detach()

# ---- train ----
y_train = train_data.y
mask_train = train_data.train_withlabel_mask
idx_train = mask_train.nonzero(as_tuple=False).view(-1)
h_train_labeled = h_train[idx_train]
y_train_labeled = y_train[idx_train]

# ---- val（全部 val 节点用于验证） ----
y_val = val_data.y

print(f"📌 Train 有标签样本数: {h_train_labeled.shape[0]}")
print(f"📌 表征维度(out_dim): {h_train_labeled.shape[1]}")


# ======================================================================
# 2. 定义分类器
# ======================================================================

num_features = h_train_labeled.size(1)
num_classes = int(max(y_train_labeled.max(), y_val.max()).item() + 1)

classifier = DownstreamClassifier(
    in_dim=num_features,
    num_classes=num_classes,
    hidden_dim=128
).to(device)

optimizer = Adam(classifier.parameters(), lr=1e-3, weight_decay=1e-4)


# ======================================================================
# 3. 整图训练 + 验证集评估（保存最佳模型）
# ======================================================================

epochs = 200
best_val_acc = 0.0
best_state = None

print("\n================== 🔥 开始下游分类训练（含 val 验证） ==================\n")

for epoch in range(1, epochs + 1):

    # ---- Train step ----
    classifier.train()
    optimizer.zero_grad()

    logits_train = classifier(h_train_labeled)
    loss = F.cross_entropy(logits_train, y_train_labeled)
    loss.backward()
    optimizer.step()

    # ---- Val step ----
    classifier.eval()
    with torch.no_grad():
        logits_val = classifier(h_val)
        pred_val = logits_val.argmax(dim=1)
        acc_val = (pred_val == y_val).float().mean().item()

    # ---- 打印 ----
    if epoch % 5 == 0:
        print(f"Epoch {epoch:03d}/{epochs} | Train Loss = {loss.item():.4f} | Val Acc = {acc_val*100:.2f}%")

    # ---- 保存最佳模型 ----
    if acc_val > best_val_acc:
        best_val_acc = acc_val
        best_state = {
            "state_dict": classifier.state_dict(),
            "in_dim": num_features,
            "num_classes": num_classes
        }

print("\n🏁 下游分类器训练完成！")
print(f"🌟 最佳验证集准确率：{best_val_acc*100:.2f}%")


# ======================================================================
# 4. 保存验证集最优模型
# ======================================================================

save_path = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/downstream/downstream_classifier_val_best.pt"

torch.save(best_state, save_path)

print(f"💾 最佳（Val Acc最高）分类器已保存：{save_path}")
# Out:
# ✅ 已添加路径：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt
# ✅ 已添加 my_lib：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/src
# 🚀 提取 train/val 编码特征（Encoder forward）...
# 📌 Train 有标签样本数: 175
# 📌 表征维度(out_dim): 256
#
# ================== 🔥 开始下游分类训练（含 val 验证） ==================
#
# Epoch 005/200 | Train Loss = 2.3862 | Val Acc = 61.46%
# Epoch 010/200 | Train Loss = 1.8579 | Val Acc = 56.25%
# Epoch 015/200 | Train Loss = 1.3034 | Val Acc = 56.25%
# Epoch 020/200 | Train Loss = 0.8349 | Val Acc = 63.54%
# Epoch 025/200 | Train Loss = 0.5252 | Val Acc = 65.62%
# Epoch 030/200 | Train Loss = 0.3406 | Val Acc = 64.58%
# Epoch 035/200 | Train Loss = 0.2310 | Val Acc = 67.71%
# Epoch 040/200 | Train Loss = 0.1631 | Val Acc = 68.75%
# Epoch 045/200 | Train Loss = 0.1182 | Val Acc = 60.42%
# Epoch 050/200 | Train Loss = 0.0881 | Val Acc = 60.42%
# Epoch 055/200 | Train Loss = 0.0676 | Val Acc = 59.38%
# Epoch 060/200 | Train Loss = 0.0532 | Val Acc = 59.38%
# Epoch 065/200 | Train Loss = 0.0432 | Val Acc = 59.38%
# Epoch 070/200 | Train Loss = 0.0358 | Val Acc = 58.33%
# Epoch 075/200 | Train Loss = 0.0302 | Val Acc = 59.38%
# Epoch 080/200 | Train Loss = 0.0260 | Val Acc = 60.42%
# Epoch 085/200 | Train Loss = 0.0226 | Val Acc = 60.42%
# Epoch 090/200 | Train Loss = 0.0200 | Val Acc = 60.42%
# Epoch 095/200 | Train Loss = 0.0178 | Val Acc = 60.42%
# Epoch 100/200 | Train Loss = 0.0160 | Val Acc = 60.42%
# Epoch 105/200 | Train Loss = 0.0145 | Val Acc = 61.46%
# Epoch 110/200 | Train Loss = 0.0133 | Val Acc = 61.46%
# Epoch 115/200 | Train Loss = 0.0122 | Val Acc = 61.46%
# Epoch 120/200 | Train Loss = 0.0112 | Val Acc = 60.42%
# Epoch 125/200 | Train Loss = 0.0104 | Val Acc = 60.42%
# Epoch 130/200 | Train Loss = 0.0096 | Val Acc = 60.42%
# Epoch 135/200 | Train Loss = 0.0090 | Val Acc = 60.42%
# Epoch 140/200 | Train Loss = 0.0084 | Val Acc = 60.42%
# Epoch 145/200 | Train Loss = 0.0079 | Val Acc = 60.42%
# Epoch 150/200 | Train Loss = 0.0074 | Val Acc = 60.42%
# Epoch 155/200 | Train Loss = 0.0070 | Val Acc = 60.42%
# Epoch 160/200 | Train Loss = 0.0066 | Val Acc = 60.42%
# Epoch 165/200 | Train Loss = 0.0062 | Val Acc = 60.42%
# Epoch 170/200 | Train Loss = 0.0059 | Val Acc = 60.42%
# Epoch 175/200 | Train Loss = 0.0056 | Val Acc = 60.42%
# Epoch 180/200 | Train Loss = 0.0053 | Val Acc = 60.42%
# Epoch 185/200 | Train Loss = 0.0051 | Val Acc = 60.42%
# Epoch 190/200 | Train Loss = 0.0048 | Val Acc = 59.38%
# Epoch 195/200 | Train Loss = 0.0046 | Val Acc = 59.38%
# Epoch 200/200 | Train Loss = 0.0044 | Val Acc = 59.38%
#
# 🏁 下游分类器训练完成！
# 🌟 最佳验证集准确率：68.75%
# 💾 最佳（Val Acc最高）分类器已保存：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/downstream/downstream_classifier_val_best.pt

# %% [markdown]
# ## 最终acc测试

# %%
# ======================================================================
#    ⭐ 单 Cell：加载上游模型 + 下游分类器，并计算 Train/Test Accuracy ⭐
# ======================================================================

import torch
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ====================== 模型路径 ======================
pretrain_path = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/KAIST_normal_pretrain_best.pt"

classifier_path = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/downstream/downstream_classifier_val_best.pt"

print("📌 模型路径已设置")


# ====================== 加载模型结构 ======================
from models import GraphContrastiveLearner, DownstreamClassifier

# ------- 加载上游 GCL 模型 -------
ckpt = torch.load(pretrain_path, map_location=device)
cfg = ckpt["config"]

model = GraphContrastiveLearner(
    in_dim     = cfg["in_dim"],
    hidden_dim = cfg["hidden_dim"],
    out_dim    = cfg["out_dim"],
    proj_dim   = cfg["proj_dim"],
    tau        = cfg["tau"] if "tau" in cfg else 0.5
).to(device)

model.load_state_dict(ckpt["model_state_dict"])   # ⭐ 不会报错的加载方式
model.eval()
print("✅ 上游模型加载成功！")


# ------- 加载下游分类器 -------
clf_ckpt = torch.load(classifier_path, map_location=device)
in_dim = clf_ckpt["in_dim"]
num_classes = clf_ckpt["num_classes"]

classifier = DownstreamClassifier(
    in_dim=in_dim,
    num_classes=num_classes,
    hidden_dim=128
).to(device)

classifier.load_state_dict(clf_ckpt["state_dict"])
classifier.eval()
print("✅ 下游分类器加载成功！")


# ====================== 加载 Train / Test 图 ======================
# 你在 notebook 中应该已经手动加载好了：
# train_data = torch.load(...)
# test_data = torch.load(...)

train_data = train_data.to(device)
test_data = test_data.to(device)

print("📌 Train/Test 图数据已加载至 GPU/CPU")


# ======================================================================
#          ⭐ 1️⃣ 提取 Train/Test 的 GCL encoder 表征 h
# ======================================================================
with torch.no_grad():
    h_train, _ = model(train_data.x, train_data.edge_index)
    h_test,  _ = model(test_data.x,  test_data.edge_index)

print("🔧 已提取上游编码特征 h_train / h_test")


# ======================================================================
#          ⭐ 2️⃣ Train Accuracy（仅 train_withlabel_mask）
# ======================================================================
train_mask = train_data.train_withlabel_mask
train_idx = train_mask.nonzero(as_tuple=False).view(-1)

h_labeled = h_train[train_idx]
y_labeled = train_data.y[train_idx]

with torch.no_grad():
    logits_train = classifier(h_labeled)
    pred_train = logits_train.argmax(dim=1)

acc_train = (pred_train == y_labeled).float().mean().item()

print(f"\n🎯 Train Accuracy (train_withlabel_mask) = {acc_train*100:.2f}%")


# ======================================================================
#          ⭐ 3️⃣ Test Accuracy（全部 test 节点）
# ======================================================================
with torch.no_grad():
    logits_test = classifier(h_test)
    pred_test = logits_test.argmax(dim=1)

acc_test = (pred_test == test_data.y).float().mean().item()

print(f"🎯 Test Accuracy  (all test nodes) = {acc_test*100:.2f}%")

print("\n🏁 全部 accuracy 评估完成！")


from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# ====================== ⭐ Train metrics ======================
y_true_train = y_labeled.cpu().numpy()
y_pred_train = pred_train.cpu().numpy()

train_acc  = accuracy_score(y_true_train, y_pred_train)
train_prec = precision_score(y_true_train, y_pred_train, average="macro", zero_division=0)
train_reca = recall_score(y_true_train, y_pred_train, average="macro", zero_division=0)
train_f1   = f1_score(y_true_train, y_pred_train, average="macro", zero_division=0)

print("\n====================== TRAIN METRICS ======================")
print(f"Accuracy : {train_acc*100:.2f}%")
print(f"Precision: {train_prec*100:.2f}%")
print(f"Recall   : {train_reca*100:.2f}%")
print(f"F1-score : {train_f1*100:.2f}%")
print("===========================================================\n")


# ====================== ⭐ Test metrics ======================
y_true_test = test_data.y.cpu().numpy()
y_pred_test = pred_test.cpu().numpy()

test_acc  = accuracy_score(y_true_test, y_pred_test)
test_prec = precision_score(y_true_test, y_pred_test, average="macro", zero_division=0)
test_reca = recall_score(y_true_test, y_pred_test, average="macro", zero_division=0)
test_f1   = f1_score(y_true_test, y_pred_test, average="macro", zero_division=0)

print("======================= TEST METRICS =======================")
print(f"Accuracy : {test_acc*100:.2f}%")
print(f"Precision: {test_prec*100:.2f}%")
print(f"Recall   : {test_reca*100:.2f}%")
print(f"F1-score : {test_f1*100:.2f}%")
print("===========================================================\n")
# ======================================================================
#          ⭐ 4️⃣ 统计预测错误的样本（真实标签 vs 预测标签）
# ======================================================================

import numpy as np
from collections import Counter

# ========== Train 错误样本 ==========
wrong_train_idx = np.where(y_pred_train != y_true_train)[0]

print("============== TRAIN WRONG PREDICTIONS ==============")
print(f"❌ 错误样本数量：{len(wrong_train_idx)} / {len(y_true_train)}")

# 打印前 20 个错误样本（避免太长）
max_show = 20
for i in wrong_train_idx[:max_show]:
    print(f"Index {i:4d} | True = {y_true_train[i]} | Pred = {y_pred_train[i]}")
if len(wrong_train_idx) > max_show:
    print(f"... (共 {len(wrong_train_idx)} 个错样本，只显示前 {max_show} 个)")

# 每类错误统计
train_wrong_pairs = [(int(y_true_train[i]), int(y_pred_train[i])) for i in wrong_train_idx]
train_wrong_count = Counter(train_wrong_pairs)

print("\n🔍 Train 每类错误统计：(真标签 -> 预测标签)")
for (t, p), cnt in train_wrong_count.items():
    print(f"  {t} → {p} : {cnt} 次")


# ========== Test 错误样本 ==========
wrong_test_idx = np.where(y_pred_test != y_true_test)[0]

print("\n============== TEST WRONG PREDICTIONS ===============")
print(f"❌ 错误样本数量：{len(wrong_test_idx)} / {len(y_true_test)}")

for i in wrong_test_idx[:max_show]:
    print(f"Index {i:4d} | True = {y_true_test[i]} | Pred = {y_pred_test[i]}")
if len(wrong_test_idx) > max_show:
    print(f"... (共 {len(wrong_test_idx)} 个错样本，只显示前 {max_show} 个)")

# 每类错误统计
test_wrong_pairs = [(int(y_true_test[i]), int(y_pred_test[i])) for i in wrong_test_idx]
test_wrong_count = Counter(test_wrong_pairs)

print("\n🔍 Test 每类错误统计：(真标签 -> 预测标签)")
for (t, p), cnt in test_wrong_count.items():
    print(f"  {t} → {p} : {cnt} 次")

print("\n🏁 错误样本统计完成！")
# Out:
# 📌 模型路径已设置
# ✅ 上游模型加载成功！
# ✅ 下游分类器加载成功！
# 📌 Train/Test 图数据已加载至 GPU/CPU
# 🔧 已提取上游编码特征 h_train / h_test
#
# 🎯 Train Accuracy (train_withlabel_mask) = 100.00%
# 🎯 Test Accuracy  (all test nodes) = 80.41%
#
# 🏁 全部 accuracy 评估完成！
# ====================== TRAIN METRICS ======================
# Accuracy : 100.00%
# Precision: 100.00%
# Recall   : 100.00%
# F1-score : 100.00%
# ===========================================================
#
# ======================= TEST METRICS =======================
# Accuracy : 80.41%
# Precision: 79.85%
# Recall   : 80.40%
# F1-score : 78.77%
# ===========================================================
#
# ============== TRAIN WRONG PREDICTIONS ==============
# ❌ 错误样本数量：0 / 175
#
# 🔍 Train 每类错误统计：(真标签 -> 预测标签)
#
# ============== TEST WRONG PREDICTIONS ===============
# ❌ 错误样本数量：57 / 291
# Index   58 | True = 1 | Pred = 11
# Index   77 | True = 11 | Pred = 12
# Index  125 | True = 12 | Pred = 13
# Index  126 | True = 12 | Pred = 13
# Index  127 | True = 12 | Pred = 13
# Index  131 | True = 12 | Pred = 14
# Index  132 | True = 12 | Pred = 13
# Index  135 | True = 12 | Pred = 13
# Index  138 | True = 12 | Pred = 13
# Index  154 | True = 12 | Pred = 11
# Index  159 | True = 12 | Pred = 14
# Index  160 | True = 12 | Pred = 11
# Index  164 | True = 12 | Pred = 14
# Index  165 | True = 12 | Pred = 11
# Index  168 | True = 12 | Pred = 13
# Index  176 | True = 13 | Pred = 12
# Index  177 | True = 13 | Pred = 12
# Index  178 | True = 13 | Pred = 12
# Index  179 | True = 13 | Pred = 12
# Index  182 | True = 13 | Pred = 12
# ... (共 57 个错样本，只显示前 20 个)
#
# 🔍 Test 每类错误统计：(真标签 -> 预测标签)
#   1 → 11 : 1 次
#   11 → 12 : 1 次
#   12 → 13 : 7 次
#   12 → 14 : 3 次
#   12 → 11 : 3 次
#   13 → 12 : 15 次
#   13 → 14 : 23 次
#   14 → 13 : 4 次
#
# 🏁 错误样本统计完成！
# /tmp/ipykernel_11988/2887444726.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(pretrain_path, map_location=device)
# /tmp/ipykernel_11988/2887444726.py:39: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   clf_ckpt = torch.load(classifier_path, map_location=device)
