# %% [markdown]
# # normal_model

# %% [markdown]
# ## time pyd_data

# %%
# ================== 1️⃣ 导入路径与函数 ==================
# %run ../_init_path.py

import os
import torch
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.utils import subgraph, add_self_loops

# === 导入模型结构 ===
from models import GraphContrastiveLearner, augment_graph, summarize_graph


# ===================== 0️⃣ 路径设置 =====================
train_graph_path = "/home/charles/HZU/Data_processed/my_CIL_V1/KAIST/KAIST_high_similar_class/train/pyg/train_graph_with_labelmask.pt"
val_graph_path   = "/home/charles/HZU/Data_processed/my_CIL_V1/KAIST/KAIST_high_similar_class/test/pyg/graph.pt"
test_graph_path  = "/home/charles/HZU/Data_processed/my_CIL_V1/KAIST/KAIST_high_similar_class/val/pyg/graph.pt"

save_dir = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT"
os.makedirs(save_dir, exist_ok=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# ===================== 1️⃣ 加载图数据 =====================
print("\n========== 加载 train 图（带 label mask） ==========")
train_data = torch.load(train_graph_path)
summarize_graph(train_data)

print("\n========== 加载 val 图 ==========")
val_data = torch.load(val_graph_path)

print("\n========== 加载 test 图 ==========")
test_data = torch.load(test_graph_path)


# ===================== 2️⃣ 对 train_data.x 做 Z-score 标准化 =====================
x_mean = train_data.x.mean(dim=0, keepdim=True)
x_std  = train_data.x.std(dim=0, keepdim=True) + 1e-6
train_data.x = (train_data.x - x_mean) / x_std

print("🎯 已完成 train_data.x 标准化")

x_mean = test_data.x.mean(dim=0, keepdim=True)
x_std  = test_data.x.std(dim=0, keepdim=True) + 1e-6
test_data.x = (test_data.x - x_mean) / x_std

print("🎯 已完成 test_data.x 标准化")

x_mean = val_data.x.mean(dim=0, keepdim=True)
x_std  = val_data.x.std(dim=0, keepdim=True) + 1e-6
val_data.x = (val_data.x - x_mean) / x_std

print("🎯 已完成 val_data.x 标准化")

# ===================== 3️⃣ 构造 batch 子图 =====================
batch_size = 128
num_nodes = train_data.num_nodes

perm = torch.randperm(num_nodes)

batches = []
for i in range(0, num_nodes, batch_size):
    node_idx = perm[i:i + batch_size]

    # ---- 提取子图（必须 CPU）----
    sub_edge_index, _ = subgraph(
        node_idx,
        train_data.edge_index,
        relabel_nodes=True
    )

    sub_x = train_data.x[node_idx]

    # ---------- ⭐ 加入自环 ----------
    sub_edge_index, _ = add_self_loops(
        sub_edge_index, num_nodes=sub_x.size(0)
    )

    sub_data = Data(
        x=sub_x,
        edge_index=sub_edge_index,
    )
    batches.append(sub_data)

print(f"📌 共生成 {len(batches)} 个子图 batch")

loader = DataLoader(batches, batch_size=1, shuffle=True)


# ===================== 4️⃣ 初始化模型 =====================
in_dim = train_data.x.size(1)
hidden_dim = 256
out_dim = 256
proj_dim = 128
tau = 0.5

model = GraphContrastiveLearner(in_dim, hidden_dim, out_dim, proj_dim, tau).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
# Out:
# ✅ 已添加路径：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt
# ✅ 已添加 my_lib：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/src
#
# ========== 加载 train 图（带 label mask） ==========
#
# ============================================================
# 🧩 Graph Data Summary
# ============================================================
# 📊 节点数量 (num_nodes): 584
# 📈 节点特征维度 (num_features): 132
# 🔗 边数量 (num_edges): 11680
# 🔁 自环数量 (self-loops): 0
# 🎯 标签维度 (y_dim): torch.Size([584])
#
# 🧾 Data对象包含字段: ['train_nolabel_mask', 'x', 'train_withlabel_mask', 'y', 'edge_index']
# ============================================================
#
#
# ========== 加载 val 图 ==========
#
# ========== 加载 test 图 ==========
# 🎯 已完成 train_data.x 标准化
# 🎯 已完成 test_data.x 标准化
# 🎯 已完成 val_data.x 标准化
# /tmp/ipykernel_3975/1640680077.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_data = torch.load(train_graph_path)
# /tmp/ipykernel_3975/1640680077.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_data = torch.load(val_graph_path)
# /tmp/ipykernel_3975/1640680077.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_data = torch.load(test_graph_path)
# 📌 共生成 5 个子图 batch

# %% [markdown]
# ## 训练

# %%
# ===================== 5️⃣ Batch 训练 =====================
epochs = 200

best_loss = float("inf")
best_model_path = os.path.join(save_dir, f"KAIST_normal_pretrain_best.pt")

print("\n================= 🚀 开始 Batch 对比学习训练 =================\n")

for epoch in range(1, epochs + 1):
    model.train()
    total_loss = 0.0

    for batch_data in loader:
        batch_data = batch_data[0].to(device)   # batch_size=1 → 取第 0 个

        # ---- 生成两份增强视图 ----
        data1 = augment_graph(
            batch_data,
            feature_drop_prob=0.2,
            edge_drop_prob=0.1,
            noise_std=0.02
        ).to(device)

        data2 = augment_graph(
            batch_data,
            feature_drop_prob=0.2,
            edge_drop_prob=0.1,
            noise_std=0.02
        ).to(device)

        # ---- 计算 InfoNCE 对比损失 ----
        loss = model.compute_loss(
            data1.x, data1.edge_index,
            data2.x, data2.edge_index
        )

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # ======== 日志输出 ========
    if epoch % 10 == 0:
        print(f"Epoch [{epoch:03d}/{epochs}] | InfoNCE Loss: {total_loss:.4f}")

    # ======== 保存当前最优模型 ========
    if total_loss < best_loss:
        best_loss = total_loss

        torch.save({
            "model_state_dict": model.state_dict(),
            "best_loss": best_loss,
            "epoch": epoch,
            "config": {
                "in_dim": in_dim,
                "hidden_dim": hidden_dim,
                "out_dim": out_dim,
                "proj_dim": proj_dim,
                "tau": tau
            }
        }, best_model_path)

        print(f"💾 [BEST MODEL UPDATED] Epoch {epoch} | Loss={total_loss:.4f}")


# ===================== 最终模型保存 =====================
final_path = os.path.join(save_dir, f"KAIST_normal_pretrain_epoch{epochs}.pt")
torch.save({
    "model_state_dict": model.state_dict(),
    "epoch": epochs,
    "config": {
        "in_dim": in_dim,
        "hidden_dim": hidden_dim,
        "out_dim": out_dim,
        "proj_dim": proj_dim,
        "tau": tau
    }
}, final_path)

print(f"\n🏁 最终模型已保存至: {final_path}")
print(f"🏆 最优模型已保存至: {best_model_path} | best_loss={best_loss:.4f}")
# Out:
# ================= 🚀 开始 Batch 对比学习训练 =================
#
# 💾 [BEST MODEL UPDATED] Epoch 1 | Loss=21.8728
# 💾 [BEST MODEL UPDATED] Epoch 2 | Loss=19.9607
# 💾 [BEST MODEL UPDATED] Epoch 3 | Loss=19.3885
# 💾 [BEST MODEL UPDATED] Epoch 4 | Loss=18.9448
# 💾 [BEST MODEL UPDATED] Epoch 5 | Loss=18.6555
# 💾 [BEST MODEL UPDATED] Epoch 6 | Loss=18.4446
# 💾 [BEST MODEL UPDATED] Epoch 7 | Loss=18.2485
# 💾 [BEST MODEL UPDATED] Epoch 8 | Loss=18.0088
# 💾 [BEST MODEL UPDATED] Epoch 9 | Loss=17.8141
# Epoch [010/200] | InfoNCE Loss: 17.6630
# 💾 [BEST MODEL UPDATED] Epoch 10 | Loss=17.6630
# 💾 [BEST MODEL UPDATED] Epoch 11 | Loss=17.5169
# 💾 [BEST MODEL UPDATED] Epoch 12 | Loss=17.3435
# 💾 [BEST MODEL UPDATED] Epoch 13 | Loss=17.1469
# 💾 [BEST MODEL UPDATED] Epoch 14 | Loss=16.9971
# 💾 [BEST MODEL UPDATED] Epoch 15 | Loss=16.8211
# 💾 [BEST MODEL UPDATED] Epoch 16 | Loss=16.6704
# 💾 [BEST MODEL UPDATED] Epoch 17 | Loss=16.4844
# 💾 [BEST MODEL UPDATED] Epoch 18 | Loss=16.3158
# 💾 [BEST MODEL UPDATED] Epoch 19 | Loss=16.1255
# Epoch [020/200] | InfoNCE Loss: 15.9815
# 💾 [BEST MODEL UPDATED] Epoch 20 | Loss=15.9815
# 💾 [BEST MODEL UPDATED] Epoch 21 | Loss=15.7819
# 💾 [BEST MODEL UPDATED] Epoch 22 | Loss=15.5416
# 💾 [BEST MODEL UPDATED] Epoch 23 | Loss=15.4163
# 💾 [BEST MODEL UPDATED] Epoch 24 | Loss=15.1963
# 💾 [BEST MODEL UPDATED] Epoch 25 | Loss=14.9267
# 💾 [BEST MODEL UPDATED] Epoch 26 | Loss=14.7431
# 💾 [BEST MODEL UPDATED] Epoch 27 | Loss=14.4763
# 💾 [BEST MODEL UPDATED] Epoch 28 | Loss=14.2598
# 💾 [BEST MODEL UPDATED] Epoch 29 | Loss=14.0138
# Epoch [030/200] | InfoNCE Loss: 13.7341
# 💾 [BEST MODEL UPDATED] Epoch 30 | Loss=13.7341
# 💾 [BEST MODEL UPDATED] Epoch 31 | Loss=13.4661
# 💾 [BEST MODEL UPDATED] Epoch 32 | Loss=13.2351
# 💾 [BEST MODEL UPDATED] Epoch 33 | Loss=12.9413
# 💾 [BEST MODEL UPDATED] Epoch 34 | Loss=12.5777
# 💾 [BEST MODEL UPDATED] Epoch 35 | Loss=12.2802
# 💾 [BEST MODEL UPDATED] Epoch 36 | Loss=11.9377
# 💾 [BEST MODEL UPDATED] Epoch 37 | Loss=11.5414
# 💾 [BEST MODEL UPDATED] Epoch 38 | Loss=11.1977
# 💾 [BEST MODEL UPDATED] Epoch 39 | Loss=10.8241
# Epoch [040/200] | InfoNCE Loss: 10.3767
# 💾 [BEST MODEL UPDATED] Epoch 40 | Loss=10.3767
# 💾 [BEST MODEL UPDATED] Epoch 41 | Loss=9.9919
# 💾 [BEST MODEL UPDATED] Epoch 42 | Loss=9.5199
# 💾 [BEST MODEL UPDATED] Epoch 43 | Loss=9.0623
# 💾 [BEST MODEL UPDATED] Epoch 44 | Loss=8.5189
# 💾 [BEST MODEL UPDATED] Epoch 45 | Loss=8.1185
# 💾 [BEST MODEL UPDATED] Epoch 46 | Loss=7.5902
# 💾 [BEST MODEL UPDATED] Epoch 47 | Loss=7.0761
# 💾 [BEST MODEL UPDATED] Epoch 48 | Loss=6.6401
# 💾 [BEST MODEL UPDATED] Epoch 49 | Loss=6.0982
# Epoch [050/200] | InfoNCE Loss: 5.6843
# 💾 [BEST MODEL UPDATED] Epoch 50 | Loss=5.6843
# 💾 [BEST MODEL UPDATED] Epoch 51 | Loss=5.2487
# 💾 [BEST MODEL UPDATED] Epoch 52 | Loss=4.9003
# 💾 [BEST MODEL UPDATED] Epoch 53 | Loss=4.5813
# 💾 [BEST MODEL UPDATED] Epoch 54 | Loss=4.3052
# 💾 [BEST MODEL UPDATED] Epoch 55 | Loss=4.0889
# 💾 [BEST MODEL UPDATED] Epoch 56 | Loss=3.8714
# 💾 [BEST MODEL UPDATED] Epoch 57 | Loss=3.7667
# 💾 [BEST MODEL UPDATED] Epoch 58 | Loss=3.6465
# 💾 [BEST MODEL UPDATED] Epoch 59 | Loss=3.5474
# Epoch [060/200] | InfoNCE Loss: 3.4866
# 💾 [BEST MODEL UPDATED] Epoch 60 | Loss=3.4866
# 💾 [BEST MODEL UPDATED] Epoch 61 | Loss=3.4323
# 💾 [BEST MODEL UPDATED] Epoch 62 | Loss=3.3877
# 💾 [BEST MODEL UPDATED] Epoch 63 | Loss=3.3620
# 💾 [BEST MODEL UPDATED] Epoch 64 | Loss=3.3258
# 💾 [BEST MODEL UPDATED] Epoch 65 | Loss=3.3078
# 💾 [BEST MODEL UPDATED] Epoch 66 | Loss=3.2923
# 💾 [BEST MODEL UPDATED] Epoch 67 | Loss=3.2904
# 💾 [BEST MODEL UPDATED] Epoch 68 | Loss=3.2660
# 💾 [BEST MODEL UPDATED] Epoch 69 | Loss=3.2552
# Epoch [070/200] | InfoNCE Loss: 3.2500
# 💾 [BEST MODEL UPDATED] Epoch 70 | Loss=3.2500
# 💾 [BEST MODEL UPDATED] Epoch 71 | Loss=3.2419
# 💾 [BEST MODEL UPDATED] Epoch 72 | Loss=3.2330
# 💾 [BEST MODEL UPDATED] Epoch 73 | Loss=3.2294
# 💾 [BEST MODEL UPDATED] Epoch 74 | Loss=3.2249
# 💾 [BEST MODEL UPDATED] Epoch 76 | Loss=3.2160
# 💾 [BEST MODEL UPDATED] Epoch 77 | Loss=3.2130
# 💾 [BEST MODEL UPDATED] Epoch 78 | Loss=3.2098
# 💾 [BEST MODEL UPDATED] Epoch 79 | Loss=3.2069
# Epoch [080/200] | InfoNCE Loss: 3.2036
# 💾 [BEST MODEL UPDATED] Epoch 80 | Loss=3.2036
# 💾 [BEST MODEL UPDATED] Epoch 81 | Loss=3.2007
# 💾 [BEST MODEL UPDATED] Epoch 82 | Loss=3.1973
# 💾 [BEST MODEL UPDATED] Epoch 83 | Loss=3.1957
# 💾 [BEST MODEL UPDATED] Epoch 84 | Loss=3.1933
# 💾 [BEST MODEL UPDATED] Epoch 85 | Loss=3.1929
# 💾 [BEST MODEL UPDATED] Epoch 86 | Loss=3.1923
# 💾 [BEST MODEL UPDATED] Epoch 87 | Loss=3.1896
# 💾 [BEST MODEL UPDATED] Epoch 88 | Loss=3.1882
# Epoch [090/200] | InfoNCE Loss: 3.1856
# 💾 [BEST MODEL UPDATED] Epoch 90 | Loss=3.1856
# 💾 [BEST MODEL UPDATED] Epoch 91 | Loss=3.1852
# 💾 [BEST MODEL UPDATED] Epoch 93 | Loss=3.1835
# 💾 [BEST MODEL UPDATED] Epoch 94 | Loss=3.1825
# 💾 [BEST MODEL UPDATED] Epoch 95 | Loss=3.1817
# 💾 [BEST MODEL UPDATED] Epoch 96 | Loss=3.1815
# 💾 [BEST MODEL UPDATED] Epoch 98 | Loss=3.1802
# 💾 [BEST MODEL UPDATED] Epoch 99 | Loss=3.1786
# Epoch [100/200] | InfoNCE Loss: 3.1786
# 💾 [BEST MODEL UPDATED] Epoch 102 | Loss=3.1781
# 💾 [BEST MODEL UPDATED] Epoch 103 | Loss=3.1773
# 💾 [BEST MODEL UPDATED] Epoch 105 | Loss=3.1770
# 💾 [BEST MODEL UPDATED] Epoch 106 | Loss=3.1762
# 💾 [BEST MODEL UPDATED] Epoch 107 | Loss=3.1759
# 💾 [BEST MODEL UPDATED] Epoch 109 | Loss=3.1744
# Epoch [110/200] | InfoNCE Loss: 3.1758
# 💾 [BEST MODEL UPDATED] Epoch 111 | Loss=3.1737
# 💾 [BEST MODEL UPDATED] Epoch 114 | Loss=3.1730
# 💾 [BEST MODEL UPDATED] Epoch 116 | Loss=3.1725
# 💾 [BEST MODEL UPDATED] Epoch 118 | Loss=3.1721
# 💾 [BEST MODEL UPDATED] Epoch 119 | Loss=3.1719
# Epoch [120/200] | InfoNCE Loss: 3.1715
# 💾 [BEST MODEL UPDATED] Epoch 120 | Loss=3.1715
# 💾 [BEST MODEL UPDATED] Epoch 122 | Loss=3.1713
# 💾 [BEST MODEL UPDATED] Epoch 124 | Loss=3.1712
# 💾 [BEST MODEL UPDATED] Epoch 125 | Loss=3.1704
# 💾 [BEST MODEL UPDATED] Epoch 128 | Loss=3.1703
# 💾 [BEST MODEL UPDATED] Epoch 129 | Loss=3.1701
# Epoch [130/200] | InfoNCE Loss: 3.1697
# 💾 [BEST MODEL UPDATED] Epoch 130 | Loss=3.1697
# 💾 [BEST MODEL UPDATED] Epoch 133 | Loss=3.1697
# 💾 [BEST MODEL UPDATED] Epoch 135 | Loss=3.1694
# 💾 [BEST MODEL UPDATED] Epoch 138 | Loss=3.1691
# 💾 [BEST MODEL UPDATED] Epoch 139 | Loss=3.1684
# Epoch [140/200] | InfoNCE Loss: 3.1689
# 💾 [BEST MODEL UPDATED] Epoch 143 | Loss=3.1682
# Epoch [150/200] | InfoNCE Loss: 3.1681
# 💾 [BEST MODEL UPDATED] Epoch 150 | Loss=3.1681
# 💾 [BEST MODEL UPDATED] Epoch 151 | Loss=3.1677
# 💾 [BEST MODEL UPDATED] Epoch 153 | Loss=3.1675
# 💾 [BEST MODEL UPDATED] Epoch 155 | Loss=3.1675
# 💾 [BEST MODEL UPDATED] Epoch 158 | Loss=3.1673
# Epoch [160/200] | InfoNCE Loss: 3.1669
# 💾 [BEST MODEL UPDATED] Epoch 160 | Loss=3.1669
# 💾 [BEST MODEL UPDATED] Epoch 167 | Loss=3.1667
# Epoch [170/200] | InfoNCE Loss: 3.1670
# 💾 [BEST MODEL UPDATED] Epoch 171 | Loss=3.1667
# 💾 [BEST MODEL UPDATED] Epoch 172 | Loss=3.1665
# 💾 [BEST MODEL UPDATED] Epoch 173 | Loss=3.1664
# 💾 [BEST MODEL UPDATED] Epoch 177 | Loss=3.1664
# 💾 [BEST MODEL UPDATED] Epoch 179 | Loss=3.1662
# Epoch [180/200] | InfoNCE Loss: 3.1665
# 💾 [BEST MODEL UPDATED] Epoch 181 | Loss=3.1661
# 💾 [BEST MODEL UPDATED] Epoch 183 | Loss=3.1660
# 💾 [BEST MODEL UPDATED] Epoch 184 | Loss=3.1658
# Epoch [190/200] | InfoNCE Loss: 3.1661
# 💾 [BEST MODEL UPDATED] Epoch 191 | Loss=3.1658
# Epoch [200/200] | InfoNCE Loss: 3.1664
#
# 🏁 最终模型已保存至: /home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/KAIST_normal_pretrain_epoch200.pt
# 🏆 最优模型已保存至: /home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/KAIST_normal_pretrain_best.pt | best_loss=3.1658

# %% [markdown]
# ## 效果可视化

# %%
# ======================================================================
#                ⭐ 单 Cell：不会报错的模型加载 + Train/Test 3D 可视化 ⭐
# ======================================================================

# ====================== 环境导入 ======================
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import umap
from mpl_toolkits.mplot3d import Axes3D

# ====================== 路径 ======================
save_dir = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/result/time_mn_hs_STFT"
os.makedirs(save_dir, exist_ok=True)

model_path = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/KAIST_normal_pretrain_best.pt"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ====================== 加载训练时的真实模型结构 ======================
from models import GraphContrastiveLearner   

# ----- 加载 checkpoint -----
checkpoint = torch.load(model_path, map_location=device)
cfg = checkpoint["config"]

# ----- 按训练时的方式实例化模型（不会报错 👍）-----
model = GraphContrastiveLearner(
    in_dim     = cfg["in_dim"],
    hidden_dim = cfg["hidden_dim"],
    out_dim    = cfg["out_dim"],
    proj_dim   = cfg["proj_dim"],
    tau        = cfg["tau"] if "tau" in cfg else 0.5
).to(device)

# ----- 加载权重（不会报错 👍）-----
model.load_state_dict(checkpoint["model_state_dict"])
model.eval()

print("✅ 使用训练时的原始模型读取成功！不会报错")

# ======================================================================
#                ⭐ 1️⃣ 提取 Train 和 Test 的嵌入
# ======================================================================

# 你前面已经：train_data / test_data = torch.load(...)
train_data = train_data.to(device)
test_data  = test_data.to(device)

with torch.no_grad():
    _, z_train = model(train_data.x, train_data.edge_index)
    _, z_test  = model(test_data.x,  test_data.edge_index)

train_emb = z_train.cpu().numpy()
test_emb  = z_test.cpu().numpy()

train_labels = train_data.y.cpu().numpy() if hasattr(train_data, "y") else np.zeros(train_emb.shape[0])
test_labels  = test_data.y.cpu().numpy() if hasattr(test_data,  "y") else np.zeros(test_emb.shape[0])

print(f"⭐ Train Embeddings Shape: {train_emb.shape}")
print(f"⭐ Test  Embeddings Shape: {test_emb.shape}")

# ======================================================================
#                ⭐ 2️⃣ 3D UMAP 降维
# ======================================================================
reducer_train = umap.UMAP(
    n_neighbors=10, min_dist=0.1, n_components=3,
    metric="cosine", random_state=42
)
train_umap = reducer_train.fit_transform(train_emb)

reducer_test = umap.UMAP(
    n_neighbors=10, min_dist=0.1, n_components=3,
    metric="cosine", random_state=42
)
test_umap = reducer_test.fit_transform(test_emb)

# ======================================================================
#                ⭐ 3️⃣ 绘制 Train 3D UMAP
# ======================================================================
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection="3d")

scatter = ax.scatter(
    train_umap[:,0], train_umap[:,1], train_umap[:,2],
    c=train_labels, cmap='tab20', s=8, alpha=0.85
)

ax.set_title("Train Graph Embeddings - 3D UMAP")
ax.set_xlabel("UMAP-1"); ax.set_ylabel("UMAP-2"); ax.set_zlabel("UMAP-3")

legend = plt.legend(
    *scatter.legend_elements(num=None),
    title="Labels", loc="center left", bbox_to_anchor=(1.02, 0.5), fontsize=8
)
ax.add_artist(legend)

plt.tight_layout(rect=[0,0,0.85,1])
plt.savefig(os.path.join(save_dir, "train_umap_3d.png"), dpi=300)
plt.show()

# ======================================================================
#                ⭐ 4️⃣ 绘制 Test 3D UMAP
# ======================================================================
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection="3d")

scatter = ax.scatter(
    test_umap[:,0], test_umap[:,1], test_umap[:,2],
    c=test_labels, cmap='tab20', s=8, alpha=0.85
)

ax.set_title("Test Graph Embeddings - 3D UMAP")
ax.set_xlabel("UMAP-1"); ax.set_ylabel("UMAP-2"); ax.set_zlabel("UMAP-3")

legend = plt.legend(
    *scatter.legend_elements(num=None),
    title="Labels", loc="center left", bbox_to_anchor=(1.02, 0.5), fontsize=8
)
ax.add_artist(legend)

plt.tight_layout(rect=[0,0,0.85,1])
plt.savefig(os.path.join(save_dir, "test_umap_3d.png"), dpi=300)
plt.show()

# ======================================================================
#                ⭐ 5️⃣ 保存嵌入
# ======================================================================
np.save(os.path.join(save_dir, "train_emb.npy"), train_emb)
np.save(os.path.join(save_dir, "train_umap_3d.npy"), train_umap)
np.save(os.path.join(save_dir, "test_emb.npy"),  test_emb)
np.save(os.path.join(save_dir, "test_umap_3d.npy"),  test_umap)

print("\n🎯 Train / Test 3D UMAP 全部完成并保存！")
# Out:
# /tmp/ipykernel_148092/2289585970.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# /home/charles/miniconda3/envs/d2l/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ 使用训练时的原始模型读取成功！不会报错
# ⭐ Train Embeddings Shape: (584, 128)
# ⭐ Test  Embeddings Shape: (96, 128)
# /home/charles/miniconda3/envs/d2l/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 🎯 Train / Test 3D UMAP 全部完成并保存！

# %% [markdown]
# ## 下游训练

# %%
# ======================================================================
#        ⭐ 单 Cell：使用 train_withlabel_mask 整图训练下游分类器（含 val 验证集） ⭐
# ======================================================================
# %run ../_init_path.py
from models import GraphContrastiveLearner, DownstreamClassifier

import torch
import torch.nn.functional as F
from torch.optim import Adam

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ======================================================================
# 1. 提取 train、val 的 encoder 表征
# ======================================================================

train_data = train_data.to(device)
val_data   = val_data.to(device)

model = model.to(device)
model.eval()

print("🚀 提取 train/val 编码特征（Encoder forward）...")

with torch.no_grad():
    h_train, _ = model(train_data.x, train_data.edge_index)
    h_val,   _ = model(val_data.x,   val_data.edge_index)

h_train = h_train.detach()
h_val   = h_val.detach()

# ---- train ----
y_train = train_data.y
mask_train = train_data.train_withlabel_mask
idx_train = mask_train.nonzero(as_tuple=False).view(-1)
h_train_labeled = h_train[idx_train]
y_train_labeled = y_train[idx_train]

# ---- val（全部 val 节点用于验证） ----
y_val = val_data.y

print(f"📌 Train 有标签样本数: {h_train_labeled.shape[0]}")
print(f"📌 表征维度(out_dim): {h_train_labeled.shape[1]}")


# ======================================================================
# 2. 定义分类器
# ======================================================================

num_features = h_train_labeled.size(1)
num_classes = int(max(y_train_labeled.max(), y_val.max()).item() + 1)

classifier = DownstreamClassifier(
    in_dim=num_features,
    num_classes=num_classes,
    hidden_dim=128
).to(device)

optimizer = Adam(classifier.parameters(), lr=1e-3, weight_decay=1e-4)


# ======================================================================
# 3. 整图训练 + 验证集评估（保存最佳模型）
# ======================================================================

epochs = 200
best_val_acc = 0.0
best_state = None

print("\n================== 🔥 开始下游分类训练（含 val 验证） ==================\n")

for epoch in range(1, epochs + 1):

    # ---- Train step ----
    classifier.train()
    optimizer.zero_grad()

    logits_train = classifier(h_train_labeled)
    loss = F.cross_entropy(logits_train, y_train_labeled)
    loss.backward()
    optimizer.step()

    # ---- Val step ----
    classifier.eval()
    with torch.no_grad():
        logits_val = classifier(h_val)
        pred_val = logits_val.argmax(dim=1)
        acc_val = (pred_val == y_val).float().mean().item()

    # ---- 打印 ----
    if epoch % 5 == 0:
        print(f"Epoch {epoch:03d}/{epochs} | Train Loss = {loss.item():.4f} | Val Acc = {acc_val*100:.2f}%")

    # ---- 保存最佳模型 ----
    if acc_val > best_val_acc:
        best_val_acc = acc_val
        best_state = {
            "state_dict": classifier.state_dict(),
            "in_dim": num_features,
            "num_classes": num_classes
        }

print("\n🏁 下游分类器训练完成！")
print(f"🌟 最佳验证集准确率：{best_val_acc*100:.2f}%")


# ======================================================================
# 4. 保存验证集最优模型
# ======================================================================

save_path = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/downstream/downstream_classifier_val_best.pt"

torch.save(best_state, save_path)

print(f"💾 最佳（Val Acc最高）分类器已保存：{save_path}")
# Out:
# ✅ 已添加路径：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt
# ✅ 已添加 my_lib：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/src
# 🚀 提取 train/val 编码特征（Encoder forward）...
# 📌 Train 有标签样本数: 175
# 📌 表征维度(out_dim): 256
#
# ================== 🔥 开始下游分类训练（含 val 验证） ==================
#
# Epoch 005/200 | Train Loss = 2.4124 | Val Acc = 28.52%
# Epoch 010/200 | Train Loss = 2.0339 | Val Acc = 35.40%
# Epoch 015/200 | Train Loss = 1.6621 | Val Acc = 40.55%
# Epoch 020/200 | Train Loss = 1.3690 | Val Acc = 41.92%
# Epoch 025/200 | Train Loss = 1.1452 | Val Acc = 59.11%
# Epoch 030/200 | Train Loss = 0.9719 | Val Acc = 60.48%
# Epoch 035/200 | Train Loss = 0.8226 | Val Acc = 57.73%
# Epoch 040/200 | Train Loss = 0.6954 | Val Acc = 60.14%
# Epoch 045/200 | Train Loss = 0.5873 | Val Acc = 61.86%
# Epoch 050/200 | Train Loss = 0.4953 | Val Acc = 61.86%
# Epoch 055/200 | Train Loss = 0.4173 | Val Acc = 59.79%
# Epoch 060/200 | Train Loss = 0.3512 | Val Acc = 60.82%
# Epoch 065/200 | Train Loss = 0.2956 | Val Acc = 60.48%
# Epoch 070/200 | Train Loss = 0.2487 | Val Acc = 59.79%
# Epoch 075/200 | Train Loss = 0.2095 | Val Acc = 60.82%
# Epoch 080/200 | Train Loss = 0.1769 | Val Acc = 61.51%
# Epoch 085/200 | Train Loss = 0.1499 | Val Acc = 61.86%
# Epoch 090/200 | Train Loss = 0.1277 | Val Acc = 62.20%
# Epoch 095/200 | Train Loss = 0.1094 | Val Acc = 61.51%
# Epoch 100/200 | Train Loss = 0.0944 | Val Acc = 61.17%
# Epoch 105/200 | Train Loss = 0.0820 | Val Acc = 60.82%
# Epoch 110/200 | Train Loss = 0.0718 | Val Acc = 60.48%
# Epoch 115/200 | Train Loss = 0.0634 | Val Acc = 60.82%
# Epoch 120/200 | Train Loss = 0.0563 | Val Acc = 61.17%
# Epoch 125/200 | Train Loss = 0.0504 | Val Acc = 60.82%
# Epoch 130/200 | Train Loss = 0.0454 | Val Acc = 60.82%
# Epoch 135/200 | Train Loss = 0.0411 | Val Acc = 60.82%
# Epoch 140/200 | Train Loss = 0.0374 | Val Acc = 60.82%
# Epoch 145/200 | Train Loss = 0.0342 | Val Acc = 60.48%
# Epoch 150/200 | Train Loss = 0.0315 | Val Acc = 60.48%
# Epoch 155/200 | Train Loss = 0.0291 | Val Acc = 60.48%
# Epoch 160/200 | Train Loss = 0.0269 | Val Acc = 60.48%
# Epoch 165/200 | Train Loss = 0.0250 | Val Acc = 60.48%
# Epoch 170/200 | Train Loss = 0.0234 | Val Acc = 60.14%
# Epoch 175/200 | Train Loss = 0.0219 | Val Acc = 60.14%
# Epoch 180/200 | Train Loss = 0.0205 | Val Acc = 60.14%
# Epoch 185/200 | Train Loss = 0.0193 | Val Acc = 60.14%
# Epoch 190/200 | Train Loss = 0.0182 | Val Acc = 60.14%
# Epoch 195/200 | Train Loss = 0.0172 | Val Acc = 60.14%
# Epoch 200/200 | Train Loss = 0.0162 | Val Acc = 59.79%
#
# 🏁 下游分类器训练完成！
# 🌟 最佳验证集准确率：62.20%
# 💾 最佳（Val Acc最高）分类器已保存：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/downstream/downstream_classifier_val_best.pt

# %% [markdown]
# ## 最终acc测试

# %%
# ======================================================================
#    ⭐ 单 Cell：加载上游模型 + 下游分类器，并计算 Train/Test Accuracy ⭐
# ======================================================================

import torch
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ====================== 模型路径 ======================
pretrain_path = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/KAIST_normal_pretrain_best.pt"

classifier_path = "/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/GCL_pre_train/KAIST_normal_model_opt/model_save/time_mn_hs_STFT/downstream/downstream_classifier.pt"

print("📌 模型路径已设置")


# ====================== 加载模型结构 ======================
from models import GraphContrastiveLearner, DownstreamClassifier

# ------- 加载上游 GCL 模型 -------
ckpt = torch.load(pretrain_path, map_location=device)
cfg = ckpt["config"]

model = GraphContrastiveLearner(
    in_dim     = cfg["in_dim"],
    hidden_dim = cfg["hidden_dim"],
    out_dim    = cfg["out_dim"],
    proj_dim   = cfg["proj_dim"],
    tau        = cfg["tau"] if "tau" in cfg else 0.5
).to(device)

model.load_state_dict(ckpt["model_state_dict"])   # ⭐ 不会报错的加载方式
model.eval()
print("✅ 上游模型加载成功！")


# ------- 加载下游分类器 -------
clf_ckpt = torch.load(classifier_path, map_location=device)
in_dim = clf_ckpt["in_dim"]
num_classes = clf_ckpt["num_classes"]

classifier = DownstreamClassifier(
    in_dim=in_dim,
    num_classes=num_classes,
    hidden_dim=128
).to(device)

classifier.load_state_dict(clf_ckpt["state_dict"])
classifier.eval()
print("✅ 下游分类器加载成功！")


# ====================== 加载 Train / Test 图 ======================
# 你在 notebook 中应该已经手动加载好了：
# train_data = torch.load(...)
# test_data = torch.load(...)

train_data = train_data.to(device)
test_data = test_data.to(device)

print("📌 Train/Test 图数据已加载至 GPU/CPU")


# ======================================================================
#          ⭐ 1️⃣ 提取 Train/Test 的 GCL encoder 表征 h
# ======================================================================
with torch.no_grad():
    h_train, _ = model(train_data.x, train_data.edge_index)
    h_test,  _ = model(test_data.x,  test_data.edge_index)

print("🔧 已提取上游编码特征 h_train / h_test")


# ======================================================================
#          ⭐ 2️⃣ Train Accuracy（仅 train_withlabel_mask）
# ======================================================================
train_mask = train_data.train_withlabel_mask
train_idx = train_mask.nonzero(as_tuple=False).view(-1)

h_labeled = h_train[train_idx]
y_labeled = train_data.y[train_idx]

with torch.no_grad():
    logits_train = classifier(h_labeled)
    pred_train = logits_train.argmax(dim=1)

acc_train = (pred_train == y_labeled).float().mean().item()

print(f"\n🎯 Train Accuracy (train_withlabel_mask) = {acc_train*100:.2f}%")


# ======================================================================
#          ⭐ 3️⃣ Test Accuracy（全部 test 节点）
# ======================================================================
with torch.no_grad():
    logits_test = classifier(h_test)
    pred_test = logits_test.argmax(dim=1)

acc_test = (pred_test == test_data.y).float().mean().item()

print(f"🎯 Test Accuracy  (all test nodes) = {acc_test*100:.2f}%")

print("\n🏁 全部 accuracy 评估完成！")


from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# ====================== ⭐ Train metrics ======================
y_true_train = y_labeled.cpu().numpy()
y_pred_train = pred_train.cpu().numpy()

train_acc  = accuracy_score(y_true_train, y_pred_train)
train_prec = precision_score(y_true_train, y_pred_train, average="macro", zero_division=0)
train_reca = recall_score(y_true_train, y_pred_train, average="macro", zero_division=0)
train_f1   = f1_score(y_true_train, y_pred_train, average="macro", zero_division=0)

print("\n====================== TRAIN METRICS ======================")
print(f"Accuracy : {train_acc*100:.2f}%")
print(f"Precision: {train_prec*100:.2f}%")
print(f"Recall   : {train_reca*100:.2f}%")
print(f"F1-score : {train_f1*100:.2f}%")
print("===========================================================\n")


# ====================== ⭐ Test metrics ======================
y_true_test = test_data.y.cpu().numpy()
y_pred_test = pred_test.cpu().numpy()

test_acc  = accuracy_score(y_true_test, y_pred_test)
test_prec = precision_score(y_true_test, y_pred_test, average="macro", zero_division=0)
test_reca = recall_score(y_true_test, y_pred_test, average="macro", zero_division=0)
test_f1   = f1_score(y_true_test, y_pred_test, average="macro", zero_division=0)

print("======================= TEST METRICS =======================")
print(f"Accuracy : {test_acc*100:.2f}%")
print(f"Precision: {test_prec*100:.2f}%")
print(f"Recall   : {test_reca*100:.2f}%")
print(f"F1-score : {test_f1*100:.2f}%")
print("===========================================================\n")
# ======================================================================
#          ⭐ 4️⃣ 统计预测错误的样本（真实标签 vs 预测标签）
# ======================================================================

import numpy as np
from collections import Counter

# ========== Train 错误样本 ==========
wrong_train_idx = np.where(y_pred_train != y_true_train)[0]

print("============== TRAIN WRONG PREDICTIONS ==============")
print(f"❌ 错误样本数量：{len(wrong_train_idx)} / {len(y_true_train)}")

# 打印前 20 个错误样本（避免太长）
max_show = 20
for i in wrong_train_idx[:max_show]:
    print(f"Index {i:4d} | True = {y_true_train[i]} | Pred = {y_pred_train[i]}")
if len(wrong_train_idx) > max_show:
    print(f"... (共 {len(wrong_train_idx)} 个错样本，只显示前 {max_show} 个)")

# 每类错误统计
train_wrong_pairs = [(int(y_true_train[i]), int(y_pred_train[i])) for i in wrong_train_idx]
train_wrong_count = Counter(train_wrong_pairs)

print("\n🔍 Train 每类错误统计：(真标签 -> 预测标签)")
for (t, p), cnt in train_wrong_count.items():
    print(f"  {t} → {p} : {cnt} 次")


# ========== Test 错误样本 ==========
wrong_test_idx = np.where(y_pred_test != y_true_test)[0]

print("\n============== TEST WRONG PREDICTIONS ===============")
print(f"❌ 错误样本数量：{len(wrong_test_idx)} / {len(y_true_test)}")

for i in wrong_test_idx[:max_show]:
    print(f"Index {i:4d} | True = {y_true_test[i]} | Pred = {y_pred_test[i]}")
if len(wrong_test_idx) > max_show:
    print(f"... (共 {len(wrong_test_idx)} 个错样本，只显示前 {max_show} 个)")

# 每类错误统计
test_wrong_pairs = [(int(y_true_test[i]), int(y_pred_test[i])) for i in wrong_test_idx]
test_wrong_count = Counter(test_wrong_pairs)

print("\n🔍 Test 每类错误统计：(真标签 -> 预测标签)")
for (t, p), cnt in test_wrong_count.items():
    print(f"  {t} → {p} : {cnt} 次")

print("\n🏁 错误样本统计完成！")
# Out:
# 📌 模型路径已设置
# ✅ 上游模型加载成功！
# ✅ 下游分类器加载成功！
# 📌 Train/Test 图数据已加载至 GPU/CPU
# 🔧 已提取上游编码特征 h_train / h_test
#
# 🎯 Train Accuracy (train_withlabel_mask) = 100.00%
# 🎯 Test Accuracy  (all test nodes) = 63.54%
#
# 🏁 全部 accuracy 评估完成！
# /tmp/ipykernel_3975/3179502758.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(pretrain_path, map_location=device)
# /tmp/ipykernel_3975/3179502758.py:39: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   clf_ckpt = torch.load(classifier_path, map_location=device)
# ====================== TRAIN METRICS ======================
# Accuracy : 100.00%
# Precision: 100.00%
# Recall   : 100.00%
# F1-score : 100.00%
# ===========================================================
#
# ======================= TEST METRICS =======================
# Accuracy : 63.54%
# Precision: 61.52%
# Recall   : 63.26%
# F1-score : 61.54%
# ===========================================================
#
# ============== TRAIN WRONG PREDICTIONS ==============
# ❌ 错误样本数量：0 / 175
#
# 🔍 Train 每类错误统计：(真标签 -> 预测标签)
#
# ============== TEST WRONG PREDICTIONS ===============
# ❌ 错误样本数量：35 / 96
# Index   19 | True = 11 | Pred = 1
# Index   41 | True = 12 | Pred = 11
# Index   43 | True = 12 | Pred = 11
# Index   46 | True = 12 | Pred = 11
# Index   47 | True = 12 | Pred = 11
# Index   48 | True = 12 | Pred = 11
# Index   49 | True = 12 | Pred = 11
# Index   51 | True = 12 | Pred = 11
# Index   52 | True = 12 | Pred = 11
# Index   53 | True = 12 | Pred = 11
# Index   54 | True = 12 | Pred = 13
# Index   55 | True = 12 | Pred = 14
# Index   56 | True = 12 | Pred = 11
# Index   58 | True = 13 | Pred = 14
# Index   59 | True = 13 | Pred = 14
# Index   60 | True = 13 | Pred = 12
# Index   61 | True = 13 | Pred = 12
# Index   62 | True = 13 | Pred = 12
# Index   65 | True = 13 | Pred = 12
# Index   66 | True = 13 | Pred = 12
# ... (共 35 个错样本，只显示前 20 个)
#
# 🔍 Test 每类错误统计：(真标签 -> 预测标签)
#   11 → 1 : 1 次
#   12 → 11 : 10 次
#   12 → 13 : 1 次
#   12 → 14 : 1 次
#   13 → 14 : 7 次
#   13 → 12 : 5 次
#   14 → 13 : 8 次
#   14 → 12 : 2 次
#
# 🏁 错误样本统计完成！
