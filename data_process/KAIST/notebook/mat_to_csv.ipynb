# %% [markdown]
# # 设置数据文件存放根目录（不直接放在该项目中，该项目有github仓库，避免大内存数据影响代码推送）

# %%
boot_file_adr = "/home/charles/HZU/Data_processed/my_CIL_V1/KAIST"

# %% [markdown]
# # mat-> csv

# %%
# ================== 导入路径与函数 ==================
# %run ../_init_path.py

from KAIST_utils import process_kaist_file
import os
from tqdm import tqdm

# ================== 基础配置 ==================
boot_file_adr = "/home/charles/HZU/Data_processed/my_CIL_V1/KAIST"
save_dir = os.path.join(boot_file_adr, "raw_csv")
os.makedirs(save_dir, exist_ok=True)

data_type = "vibration"

# ================== 要处理的文件列表（仅你给出的那部分） ==================
mat_files = [
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_BPFI_03.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_BPFI_10.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_BPFI_30.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_BPFO_03.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_BPFO_10.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_BPFO_30.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_Misalign_01.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_Misalign_03.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_Misalign_05.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_Normal.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_Unbalance_0583mg.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_Unbalance_1169mg.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_Unbalance_1751mg.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_Unbalance_2239mg.mat",
    "/home/charles/HZU/Data_raw/KAIST/Vibration, Acoustic, Temperature, and Motor Current Dataset of Rotating Machine Under Varying Load Conditions for Fault Diagnosis/vibration/0Nm_Unbalance_3318mg.mat",
]

print(f"🎯 本次只转换 {len(mat_files)} 个文件")

# ================== 批量转换 ==================
converted_files = []
for file_path in tqdm(mat_files, desc="Processing selected KAIST vibration data"):
    try:
        csv_path = process_kaist_file(file_path, save_dir, data_type)
        converted_files.append(csv_path)
    except Exception as e:
        print(f"❌ 文件 {os.path.basename(file_path)} 处理失败：{e}")

print("\n✅ 全部完成！")
print(f"共成功转换 {len(converted_files)} 个文件，保存至：{save_dir}")
# Out:
# ✅ 已添加路径：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/data_process/KAIST
# ✅ 已添加 my_lib：/home/charles/HZU/Industrial_Software_Testing/Industrial_Software_Testing/my_CIL_V1/data_process/KAIST/my_lib
# 🎯 本次只转换 15 个文件
# Processing selected KAIST vibration data: 100%|██████████| 15/15 [17:09<00:00, 68.62s/it]
# ✅ 全部完成！
# 共成功转换 15 个文件，保存至：/home/charles/HZU/Data_processed/my_CIL_V1/KAIST/raw_csv
